# %%
import pandas as pd

# %%
#Datas
df = pd.DataFrame({
        'age':[70,30,22,19,45,33,20],
        'num_children':[4,2,1,0,3,1,0],
        })

# %%
#Scatter plot
ax1 = df.plot.scatter(title='Scatter plot: Number of children and age',x='age', y='num_children', c='red')
