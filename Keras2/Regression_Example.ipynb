# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'car name']
df = pd.read_csv(url, names=column_names, na_values='?', comment='\t', sep=' ', skipinitialspace=True)

for column in df.columns:
    if df[column].dtype != object:
        df[column] = df[column].fillna(df[column].median())


df = df.drop(['model year', 'origin', 'car name'], axis=1)


X = df.drop('mpg', axis=1)
y = df['mpg']


X_train, X_test = X.iloc[:-79], X.iloc[-79:]
y_train, y_test = y.iloc[:-79], y.iloc[-79:]

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"X_train_scaled shape: {X_train_scaled.shape}")
print("First 5 rows of X_train_scaled:")
print(pd.DataFrame(X_train_scaled[:5], columns=X.columns))

print(f"\nX_test_scaled shape: {X_test_scaled.shape}")
print("First 5 rows of X_test_scaled:")
print(pd.DataFrame(X_test_scaled[:5], columns=X.columns))

print("\nFirst 5 values of y_train:")
print(y_train.head())

print("\nFirst 5 values of y_test:")
print(y_test.head())

model = Sequential([
    Dense(30, input_dim=5, activation='sigmoid'),
    Dense(30, activation='sigmoid'),
    Dense(1)
])

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

history = model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=0)

test_loss, test_mae = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f"\nMean Absolute Error sur l'ensemble de test: {test_mae:.2f}")

if test_mae < 10:
    print("Le modèle a atteint l'objectif d'un MAE inférieur à 10 sur l'ensemble de test.")
else:
    print("Le modèle n'a pas atteint l'objectif d'un MAE inférieur à 10 sur l'ensemble de test.")
# Out:
# Training model...
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 442.8930 - mean_absolute_error: 19.9003 - val_loss: 599.3982 - val_mean_absolute_error: 23.5782
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 406.6682 - mean_absolute_error: 19.0957 - val_loss: 581.7074 - val_mean_absolute_error: 23.2032
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 382.9897 - mean_absolute_error: 18.5062 - val_loss: 564.3475 - val_mean_absolute_error: 22.8295
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 358.6340 - mean_absolute_error: 17.9713 - val_loss: 547.3889 - val_mean_absolute_error: 22.4589
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 369.3146 - mean_absolute_error: 18.1663 - val_loss: 530.7520 - val_mean_absolute_error: 22.0900
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 358.7723 - mean_absolute_error: 17.8857 - val_loss: 514.7410 - val_mean_absolute_error: 21.7294
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 330.9464 - mean_absolute_error: 17.0974 - val_loss: 499.4292 - val_mean_absolute_error: 21.3789
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 321.1352 - mean_absolute_error: 16.7524 - val_loss: 484.6589 - val_mean_absolute_error: 21.0359
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 310.8515 - mean_absolute_error: 16.3808 - val_loss: 470.5815 - val_mean_absolute_error: 20.7039
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 308.4502 - mean_absolute_error: 16.3858 - val_loss: 457.0855 - val_mean_absolute_error: 20.3808
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 297.3126 - mean_absolute_error: 16.1525 - val_loss: 444.3369 - val_mean_absolute_error: 20.0704
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 278.1795 - mean_absolute_error: 15.4033 - val_loss: 432.3353 - val_mean_absolute_error: 19.7735
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 287.6510 - mean_absolute_error: 15.7541 - val_loss: 420.8240 - val_mean_absolute_error: 19.4845
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 273.0866 - mean_absolute_error: 15.3378 - val_loss: 410.0304 - val_mean_absolute_error: 19.2086
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 243.5269 - mean_absolute_error: 14.4016 - val_loss: 399.9241 - val_mean_absolute_error: 18.9457
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 270.1032 - mean_absolute_error: 15.2676 - val_loss: 390.1143 - val_mean_absolute_error: 18.6873
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 229.7067 - mean_absolute_error: 13.9587 - val_loss: 381.0505 - val_mean_absolute_error: 18.4439
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 234.2648 - mean_absolute_error: 14.0960 - val_loss: 372.3198 - val_mean_absolute_error: 18.2063
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 235.3322 - mean_absolute_error: 14.0545 - val_loss: 364.0329 - val_mean_absolute_error: 17.9773
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 202.0701 - mean_absolute_error: 13.1160 - val_loss: 356.2164 - val_mean_absolute_error: 17.7578
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 211.6586 - mean_absolute_error: 13.2747 - val_loss: 348.6706 - val_mean_absolute_error: 17.5431
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 203.3277 - mean_absolute_error: 13.0102 - val_loss: 341.4688 - val_mean_absolute_error: 17.3356
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 207.0733 - mean_absolute_error: 13.0328 - val_loss: 334.5540 - val_mean_absolute_error: 17.1335
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 193.4626 - mean_absolute_error: 12.5018 - val_loss: 327.9438 - val_mean_absolute_error: 16.9375
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 202.6737 - mean_absolute_error: 12.8339 - val_loss: 321.5186 - val_mean_absolute_error: 16.7453
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 202.0550 - mean_absolute_error: 12.6827 - val_loss: 315.3671 - val_mean_absolute_error: 16.5587
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 174.5193 - mean_absolute_error: 11.8345 - val_loss: 309.4848 - val_mean_absolute_error: 16.3779
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 175.5917 - mean_absolute_error: 11.7606 - val_loss: 303.7934 - val_mean_absolute_error: 16.2009
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 169.9178 - mean_absolute_error: 11.7547 - val_loss: 298.2109 - val_mean_absolute_error: 16.0259
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 155.0399 - mean_absolute_error: 10.9751 - val_loss: 292.8450 - val_mean_absolute_error: 15.8555
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 172.6918 - mean_absolute_error: 11.6353 - val_loss: 287.5405 - val_mean_absolute_error: 15.6859
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 166.2268 - mean_absolute_error: 11.2897 - val_loss: 282.4302 - val_mean_absolute_error: 15.5203
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 163.3929 - mean_absolute_error: 11.2541 - val_loss: 277.4535 - val_mean_absolute_error: 15.3574
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 163.0926 - mean_absolute_error: 11.1014 - val_loss: 272.6157 - val_mean_absolute_error: 15.1975
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 145.3366 - mean_absolute_error: 10.5863 - val_loss: 267.9187 - val_mean_absolute_error: 15.0405
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 143.1761 - mean_absolute_error: 10.2673 - val_loss: 263.3211 - val_mean_absolute_error: 14.8853
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 145.5973 - mean_absolute_error: 10.4655 - val_loss: 258.7691 - val_mean_absolute_error: 14.7305
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 139.4502 - mean_absolute_error: 10.1391 - val_loss: 254.3288 - val_mean_absolute_error: 14.5778
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 148.1811 - mean_absolute_error: 10.3449 - val_loss: 249.9428 - val_mean_absolute_error: 14.4257
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 140.7112 - mean_absolute_error: 10.0977 - val_loss: 245.6306 - val_mean_absolute_error: 14.2746
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 132.4297 - mean_absolute_error: 10.0681 - val_loss: 241.3989 - val_mean_absolute_error: 14.1249
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 127.5499 - mean_absolute_error: 9.5185 - val_loss: 237.2573 - val_mean_absolute_error: 13.9768
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 124.2106 - mean_absolute_error: 9.2580 - val_loss: 233.1505 - val_mean_absolute_error: 13.8285
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 129.0437 - mean_absolute_error: 9.6439 - val_loss: 229.0784 - val_mean_absolute_error: 13.6802
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 134.2042 - mean_absolute_error: 9.5435 - val_loss: 225.0589 - val_mean_absolute_error: 13.5323
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 111.4700 - mean_absolute_error: 8.8423 - val_loss: 221.1846 - val_mean_absolute_error: 13.3879
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 126.7048 - mean_absolute_error: 9.2172 - val_loss: 217.3415 - val_mean_absolute_error: 13.2433
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 120.7270 - mean_absolute_error: 9.0060 - val_loss: 213.5962 - val_mean_absolute_error: 13.1008
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 110.9832 - mean_absolute_error: 8.6468 - val_loss: 209.9152 - val_mean_absolute_error: 12.9593
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 111.3524 - mean_absolute_error: 8.7255 - val_loss: 206.3218 - val_mean_absolute_error: 12.8196
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 107.9126 - mean_absolute_error: 8.3563 - val_loss: 202.7883 - val_mean_absolute_error: 12.6808
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 105.4118 - mean_absolute_error: 8.4054 - val_loss: 199.3240 - val_mean_absolute_error: 12.5433
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 112.0479 - mean_absolute_error: 8.4657 - val_loss: 195.9301 - val_mean_absolute_error: 12.4072
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 99.6866 - mean_absolute_error: 8.0310 - val_loss: 192.6170 - val_mean_absolute_error: 12.2729
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 103.8767 - mean_absolute_error: 8.1944 - val_loss: 189.3551 - val_mean_absolute_error: 12.1393
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 100.9507 - mean_absolute_error: 7.9485 - val_loss: 186.1491 - val_mean_absolute_error: 12.0067
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 103.8879 - mean_absolute_error: 8.1148 - val_loss: 182.9712 - val_mean_absolute_error: 11.8741
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 103.3102 - mean_absolute_error: 8.0473 - val_loss: 179.8511 - val_mean_absolute_error: 11.7424
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 97.0421 - mean_absolute_error: 7.8077 - val_loss: 176.7689 - val_mean_absolute_error: 11.6112
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 88.7010 - mean_absolute_error: 7.3223 - val_loss: 173.7469 - val_mean_absolute_error: 11.4812
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 89.9078 - mean_absolute_error: 7.3489 - val_loss: 170.7351 - val_mean_absolute_error: 11.3504
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 90.5441 - mean_absolute_error: 7.3831 - val_loss: 167.7981 - val_mean_absolute_error: 11.2216
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 82.4181 - mean_absolute_error: 6.7488 - val_loss: 164.9441 - val_mean_absolute_error: 11.0950
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 77.8290 - mean_absolute_error: 6.6788 - val_loss: 162.1101 - val_mean_absolute_error: 10.9679
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 79.0348 - mean_absolute_error: 6.6460 - val_loss: 159.3348 - val_mean_absolute_error: 10.8423
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 78.5523 - mean_absolute_error: 6.8445 - val_loss: 156.5720 - val_mean_absolute_error: 10.7159
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 75.9183 - mean_absolute_error: 6.5146 - val_loss: 153.9569 - val_mean_absolute_error: 10.5948
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 87.0531 - mean_absolute_error: 7.1680 - val_loss: 151.3377 - val_mean_absolute_error: 10.4724
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 73.4725 - mean_absolute_error: 6.4805 - val_loss: 148.8539 - val_mean_absolute_error: 10.3549
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 67.4913 - mean_absolute_error: 6.1029 - val_loss: 146.4574 - val_mean_absolute_error: 10.2406
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 72.6980 - mean_absolute_error: 6.3331 - val_loss: 144.0861 - val_mean_absolute_error: 10.1264
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 68.2845 - mean_absolute_error: 6.1259 - val_loss: 141.7919 - val_mean_absolute_error: 10.0148
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 66.3256 - mean_absolute_error: 5.9803 - val_loss: 139.5487 - val_mean_absolute_error: 9.9046
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 69.1275 - mean_absolute_error: 6.1345 - val_loss: 137.3459 - val_mean_absolute_error: 9.7957
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 67.0278 - mean_absolute_error: 6.2359 - val_loss: 135.2090 - val_mean_absolute_error: 9.6891
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 70.7711 - mean_absolute_error: 6.3633 - val_loss: 133.1122 - val_mean_absolute_error: 9.5837
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 68.9025 - mean_absolute_error: 6.3696 - val_loss: 131.0545 - val_mean_absolute_error: 9.4793
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 59.2702 - mean_absolute_error: 5.6199 - val_loss: 129.1201 - val_mean_absolute_error: 9.3805
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 64.8801 - mean_absolute_error: 6.0277 - val_loss: 127.1654 - val_mean_absolute_error: 9.2800
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 61.1472 - mean_absolute_error: 5.6957 - val_loss: 125.3019 - val_mean_absolute_error: 9.1838
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 54.3649 - mean_absolute_error: 5.4540 - val_loss: 123.4894 - val_mean_absolute_error: 9.0895
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.9418 - mean_absolute_error: 5.6792 - val_loss: 121.6708 - val_mean_absolute_error: 8.9939
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 61.9963 - mean_absolute_error: 5.8095 - val_loss: 119.8763 - val_mean_absolute_error: 8.8991
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 61.1123 - mean_absolute_error: 5.8634 - val_loss: 118.1618 - val_mean_absolute_error: 8.8080
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 56.7829 - mean_absolute_error: 5.4109 - val_loss: 116.4956 - val_mean_absolute_error: 8.7205
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.7458 - mean_absolute_error: 5.4075 - val_loss: 114.8768 - val_mean_absolute_error: 8.6364
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.3337 - mean_absolute_error: 5.1341 - val_loss: 113.2696 - val_mean_absolute_error: 8.5523
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.0356 - mean_absolute_error: 5.3782 - val_loss: 111.6863 - val_mean_absolute_error: 8.4690
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.5248 - mean_absolute_error: 5.2347 - val_loss: 110.1494 - val_mean_absolute_error: 8.3877
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.5041 - mean_absolute_error: 5.4766 - val_loss: 108.6283 - val_mean_absolute_error: 8.3072
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 51.1910 - mean_absolute_error: 5.2561 - val_loss: 107.1516 - val_mean_absolute_error: 8.2278
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.8122 - mean_absolute_error: 5.0575 - val_loss: 105.7423 - val_mean_absolute_error: 8.1521
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 49.3180 - mean_absolute_error: 4.9698 - val_loss: 104.3247 - val_mean_absolute_error: 8.0764
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 58.8085 - mean_absolute_error: 5.4888 - val_loss: 102.8887 - val_mean_absolute_error: 8.0009
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.1842 - mean_absolute_error: 4.8856 - val_loss: 101.5583 - val_mean_absolute_error: 7.9316
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.2111 - mean_absolute_error: 5.2063 - val_loss: 100.2078 - val_mean_absolute_error: 7.8598
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.9765 - mean_absolute_error: 4.5584 - val_loss: 98.9175 - val_mean_absolute_error: 7.7903
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 38.2512 - mean_absolute_error: 4.5363 - val_loss: 97.6583 - val_mean_absolute_error: 7.7235
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 48.2113 - mean_absolute_error: 4.8994 - val_loss: 96.3683 - val_mean_absolute_error: 7.6535
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.3443 - mean_absolute_error: 4.5520 - val_loss: 95.1571 - val_mean_absolute_error: 7.5873
#
# Test Mean Absolute Error: 14.20
#
# Sample predictions vs actual values:
# Predicted: 17.9, Actual: 31.3
# Predicted: 17.8, Actual: 37.0
# Predicted: 17.9, Actual: 32.2
# Predicted: 17.9, Actual: 46.6
# Predicted: 17.8, Actual: 27.9
